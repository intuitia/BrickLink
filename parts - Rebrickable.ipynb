# %%
import pandas as pd

file_path = r'C:\Users\brydo\Documents\GitHub\BrickLink\parts - Rebrickable, original (30.12.2024, 07.08 A.M.).csv'
LEGO_Parts = pd.read_csv(file_path, index_col = 0)

LEGO_Parts.head(10)
# Out:
#                                                 name  part_cat_id  \
# part_num
# 003381                   Sticker Sheet for Set 663-1           58
# 003383           Sticker Sheet for Sets 618-1, 628-2           58
# 003402    Sticker Sheet for Sets 310-3, 311-1, 312-3           58
# 003429                  Sticker Sheet for Set 1550-1           58
# 003432    Sticker Sheet for Sets 357-1, 355-1, 940-1           58
# 003434     Sticker Sheet for Set 575-2, 653-1, 460-1           58
# 003435                   Sticker Sheet for Set 687-1           58
# 003436                   Sticker Sheet for Set 180-1           58
# 003437                   Sticker Sheet for Set 181-1           58
# 003438                   Sticker Sheet for Set 131-1           58
#
#          part_material
# part_num
# 003381         Plastic
# 003383         Plastic
# 003402         Plastic
# 003429         Plastic
# 003432         Plastic
# 003434         Plastic
# 003435         Plastic
# 003436         Plastic
# ...
